# %% [markdown]
# # Introduccion al Data Wrangling

# %%
import pandas as pd
import numpy as np
import random

# %%
data = pd.read_csv('datasets/customer-churn-model/Customer Churn Model.txt')
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 0             25     265.1        110       45.07   ...           99
# 1             26     161.6        123       27.47   ...          103
# 2              0     243.4        114       41.38   ...          110
# 3              0     299.4         71       50.90   ...           88
# 4              0     166.7        113       28.34   ...          122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %% [markdown]
# ## Crear un sub-conjunto de datos

# %%
account_length = data[['Account Length','Phone','Eve Charge','Day Calls']]

# %%
account_length.head()
# Out:
#    Account Length     Phone  Eve Charge  Day Calls
# 0             128  382-4657       16.78        110
# 1             107  371-7191       16.62        123
# 2             137  358-1921       10.30        114
# 3              84  375-9999        5.26         71
# 4              75  330-6626       12.61        113

# %%
desired_columns = ['Account Length', 'Phone', 'Eve Charge', 'Day Calls']
subset = data[desired_columns]
subset.head()
# Out:
#    Account Length     Phone  Eve Charge  Day Calls
# 0             128  382-4657       16.78        110
# 1             107  371-7191       16.62        123
# 2             137  358-1921       10.30        114
# 3              84  375-9999        5.26         71
# 4              75  330-6626       12.61        113

# %%
desired_columns = ['Account Length', 'VMail Message', 'Day Calls']
all_colums_list = data.columns.values.tolist()
len(all_colums_list)
# Out:
# 21

# %%
sublist = [x for x in all_colums_list if x not in desired_columns]
len(sublist)
# Out:
# 18

# %%
subset = data[sublist]
subset.head()
# Out:
#   State  Area Code     Phone Int'l Plan VMail Plan  Day Mins  Day Charge  \
# 0    KS        415  382-4657         no        yes     265.1       45.07
# 1    OH        415  371-7191         no        yes     161.6       27.47
# 2    NJ        415  358-1921         no         no     243.4       41.38
# 3    OH        408  375-9999        yes         no     299.4       50.90
# 4    OK        415  330-6626        yes         no     166.7       28.34
#
#    Eve Mins  Eve Calls  Eve Charge  Night Mins  Night Calls  Night Charge  \
# 0     197.4         99       16.78       244.7           91         11.01
# 1     195.5        103       16.62       254.4          103         11.45
# 2     121.2        110       10.30       162.6          104          7.32
# 3      61.9         88        5.26       196.9           89          8.86
# 4     148.3        122       12.61       186.9          121          8.41
#
#    Intl Mins  Intl Calls  Intl Charge  CustServ Calls  Churn?
# ...

# %%
a = set(desired_columns)
b = set(all_colums_list)
sublist = b-a
sublist = list(sublist)
subset = data[sublist]
subset.head()
# Out:
#    Eve Calls  Eve Charge  Day Mins  Night Charge  CustServ Calls  Churn?  \
# 0         99       16.78     265.1         11.01               1  False.
# 1        103       16.62     161.6         11.45               1  False.
# 2        110       10.30     243.4          7.32               0  False.
# 3         88        5.26     299.4          8.86               2  False.
# 4        122       12.61     166.7          8.41               3  False.
#
#    Eve Mins  Intl Calls  Night Calls VMail Plan  Intl Charge Int'l Plan  \
# 0     197.4           3           91        yes         2.70         no
# 1     195.5           3          103        yes         3.70         no
# 2     121.2           5          104         no         3.29         no
# 3      61.9           7           89         no         1.78        yes
# 4     148.3           3          121         no         2.73        yes
#
#    Area Code  Intl Mins     Phone  Day Charge State  Night Mins
# ...

# %%
data[3320:]
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 3320    GA             122        510  411-5677        yes         no
# 3321    VT              60        415  400-2738         no         no
# 3322    MD              62        408  409-1856         no         no
# 3323    IN             117        415  362-5899         no         no
# 3324    WV             159        415  377-1164         no         no
# 3325    OH              78        408  368-8555         no         no
# 3326    OH              96        415  347-6812         no         no
# 3327    SC              79        415  348-3830         no         no
# 3328    AZ             192        415  414-4276         no        yes
# 3329    WV              68        415  370-3271         no         no
# 3330    RI              28        510  328-8230         no         no
# 3331    CT             184        510  364-6381        yes         no
# ...

# %% [markdown]
# ## usuarios con total Mins > 500

# %%
data1 = data[data['Day Mins']>200]
data1
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0       KS             128        415  382-4657         no        yes
# 2       NJ             137        415  358-1921         no         no
# 3       OH              84        408  375-9999        yes         no
# 5       AL             118        510  391-8027        yes         no
# 6       MA             121        510  355-9993         no        yes
# 9       WV             141        415  330-8173        yes        yes
# 15      NY             161        415  351-7269         no         no
# 19      TX              73        415  373-2782         no         no
# 26      WY              57        408  357-3817         no        yes
# 31      NH              75        510  370-3359         no         no
# 32      LA             172        408  383-1121         no         no
# 33      AZ              12        408  360-1596         no         no
# ...

# %% [markdown]
# ### Usuarios de NY que hablan menos de 200 minitos en el dia

# %%
data2 = data[(data['State']=='NY') & (data['Day Mins']<200)]

# %%
data2
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 77      NY             144        408  360-1171         no         no
# 136     NY              75        415  374-8525         no        yes
# 182     NY              67        408  405-2888         no        yes
# 186     NY             106        408  422-1471         no         no
# 373     NY              32        415  364-3567         no         no
# 530     NY              47        415  391-1348         no        yes
# 539     NY              59        408  415-4609         no         no
# 597     NY              39        408  356-1889         no         no
# 678     NY              65        510  383-8878         no         no
# 964     NY               9        408  353-1941         no        yes
# 1007    NY             181        408  340-9200         no         no
# 1011    NY              11        415  401-4650         no         no
# ...

# %% [markdown]
# ### Son de NY o hablan menos de 200 mins por dia

# %%
data3 = data[(data['State']=='NY') | (data['Day Mins']<200)]
data3
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 1       OH             107        415  371-7191         no        yes
# 4       OK              75        415  330-6626        yes         no
# 7       MO             147        415  329-9001        yes         no
# 8       LA             117        408  335-4719         no         no
# 10      IN              65        415  329-6603         no         no
# 11      RI              74        415  344-9403         no         no
# 12      IA             168        408  363-1107         no         no
# 13      MT              95        510  394-8006         no         no
# 14      IA              62        415  366-9238         no         no
# 15      NY             161        415  351-7269         no         no
# 16      ID              85        408  350-8884         no        yes
# 17      VT              93        510  386-2923         no         no
# ...

# %% [markdown]
# ## subconjuntos del data set orginal

# %%
# queremos minutos de dia, de noche de los primeros 50 individuos
subset_first_50 = data[['Day Mins', 'Night Mins', 'Account Length']][:50]
subset_first_50.shape
# Out:
# (50, 3)

# %%
data.loc[:49,['Day Mins', 'Night Mins', 'Account Length']]
# Out:
#     Day Mins  Night Mins  Account Length
# 0      265.1       244.7             128
# 1      161.6       254.4             107
# 2      243.4       162.6             137
# 3      299.4       196.9              84
# 4      166.7       186.9              75
# 5      223.4       203.9             118
# 6      218.2       212.6             121
# 7      157.0       211.8             147
# 8      184.5       215.8             117
# 9      258.6       326.4             141
# 10     129.1       208.8              65
# 11     187.7       196.0              74
# 12     128.8       141.1             168
# 13     156.6       192.3              95
# 14     120.7       203.0              62
# 15     332.9       160.6             161
# 16     196.4        89.3              85
# 17     190.7       129.6              93
# 18     189.7       165.7              76
# 19     224.4       192.8              73
# 20     155.1       208.8             147
# 21      62.4       209.6              77
# ...

# %%
data['Total Mins'] = data['Day Mins'] + data['Night Mins'] + data['Eve Mins']

# %%
data['Total Mins'].head()
# Out:
# 0    707.2
# 1    611.5
# 2    527.2
# 3    558.2
# 4    501.9
# Name: Total Mins, dtype: float64

# %%
data['Total Calls'] = data['Day Calls'] + data['Night Calls'] + data['Eve Calls']
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge     ...       Night Mins  \
# 0             25     265.1        110       45.07     ...            244.7
# 1             26     161.6        123       27.47     ...            254.4
# 2              0     243.4        114       41.38     ...            162.6
# 3              0     299.4         71       50.90     ...            196.9
# 4              0     166.7        113       28.34     ...            186.9
#
#    Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %% [markdown]
# ## Generacion de numeros aletorios

# %%
np.random.randint(1,100)
# Out:
# 93

# %%
#forma clasica entre 0 1 con decimales
np.random.random()
# Out:
# 0.3133090346821523

# %%
def randListGenerator(dimension, a, b):
    rand_list = []
    for i in range(dimension):
        rand_list.append(np.random.random()*(b-a) + a)
    return rand_list

# %%
randListGenerator(10,5,10)
# Out:
# [9.48548003262641,
#  7.168279462338806,
#  5.097473948022418,
#  8.631807733170845,
#  9.162261352237088,
#  8.458730386933961,
#  6.530447928347665,
#  8.923668983033574,
#  9.071472316319976,
#  7.690595058251436]

# %%
for i in range(10):
    print(random.randrange(0,100, 7))
# Out:
# 0
# 84
# 35
# 42
# 98
# 56
# 35
# 21
# 14
# 7

# %% [markdown]
# #### Shuffling

# %%
a = np.arange(100)

# %%
np.random.shuffle(a)

# %%
a
# Out:
# array([75, 41, 71, 32, 98, 86, 88, 65, 89, 87, 90, 68, 85, 36, 73, 93, 43,
#        12, 25,  1, 96, 69, 10, 26, 15, 76, 74, 94, 84, 11, 48, 38, 92,  0,
#        35, 13, 91, 66, 56, 27, 50, 81, 18,  2, 17, 97, 53, 54, 78, 16, 21,
#        99, 23, 95, 37, 39, 77, 45, 80,  6, 63, 42, 30,  8, 40,  9,  5, 70,
#        57, 24, 29, 51, 79, 72,  4, 34, 67, 19, 31, 60, 20, 83, 59, 64, 22,
#        47,  7, 61,  3, 49, 14, 28, 82, 62, 55, 46, 58, 52, 33, 44])

# %%
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge     ...       Night Mins  \
# 0             25     265.1        110       45.07     ...            244.7
# 1             26     161.6        123       27.47     ...            254.4
# 2              0     243.4        114       41.38     ...            162.6
# 3              0     299.4         71       50.90     ...            196.9
# 4              0     166.7        113       28.34     ...            186.9
#
#    Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
data.shape
# Out:
# (3333, 23)

# %%
column_list = data.columns.values.tolist()

# %%
x= [np.random.choice(column_list),np.random.choice(column_list),np.random.choice(column_list)]
x
# Out:
# ['Eve Calls', 'Total Calls', 'Day Calls']

# %% [markdown]
# ### seed

# %%
np.random.seed(2018)
for i in range(5):
    print(np.random.random())
# Out:
# 0.8823493117539459
# 0.10432773786047767
# 0.9070093335163405
# 0.3063988986063515
# 0.446408872427422

# %%
# Out:
# 0.8823493117539459
# 0.10432773786047767
# 0.9070093335163405
# 0.3063988986063515
# 0.446408872427422
