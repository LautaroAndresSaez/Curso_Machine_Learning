# %% [markdown]
# # Funciones de probabilidad

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = 1
b = 100
n = 2000
data = np.random.uniform(a, b, n)

# %%
plt.hist(data)
# Out:
# (array([194., 198., 197., 210., 199., 206., 199., 216., 176., 205.]),
#  array([ 1.02150337, 10.9168451 , 20.81218682, 30.70752855, 40.60287028,
#         50.49821201, 60.39355374, 70.28889546, 80.18423719, 90.07957892,
#         99.97492065]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## distribucion normal

# %%
n = 10000
data = np.random.randn(n)

# %%
x = range(1,n+1)
plt.plot(x,data)

# %%
plt.hist(data,14)
# Out:
# (array([  10.,   43.,  152.,  425.,  813., 1425., 1921., 2066., 1553.,
#          934.,  444.,  143.,   60.,   11.]),
#  array([-3.5917259 , -3.08500727, -2.57828863, -2.07157   , -1.56485137,
#         -1.05813274, -0.55141411, -0.04469548,  0.46202315,  0.96874178,
#          1.47546041,  1.98217904,  2.48889767,  2.9956163 ,  3.50233493]),
#  <a list of 14 Patch objects>)

# %%
plt.plot(x,sorted(data))

# %%
mu = 5.5
sd = 2.5
data = mu + sd*np.random.randn(n)
plt.hist(data,14)
# Out:
# (array([   4.,   14.,   94.,  303.,  811., 1515., 2064., 2106., 1627.,
#          943.,  366.,  114.,   34.,    5.]),
#  array([-4.32439983, -2.94412119, -1.56384256, -0.18356393,  1.1967147 ,
#          2.57699333,  3.95727196,  5.33755059,  6.71782922,  8.09810785,
#          9.47838648, 10.85866511, 12.23894374, 13.61922237, 14.999501  ]),
#  <a list of 14 Patch objects>)

# %%
data = np.random.rand(2,10000)

# %%
data
# Out:
# array([[0.37754056, 0.44594314, 0.53911858, ..., 0.23932748, 0.15389956,
#         0.45176475],
#        [0.42459256, 0.67609355, 0.44250973, ..., 0.69115976, 0.80202143,
#         0.14253167]])

# %% [markdown]
# ## Metodo de Monte-Carlo

# %% [markdown]
# * paso 1: genero 2 numeros (x e y) aletorios entre 0 1
# * paso 2: calcularemos x^2 + y^2
#     * si el valor es inferior a 1 estoy dentro del circulo
#     * si el valor es superior a 1 estoy fuera del circulo
# * paso 3: calculamos el numero total de puntos que estan dentro del circulo y lo dividimos por el numero total de intentos
# * paso 4: multiplico por 4 y aproximo pi
# * paso 5: repetimos el experimento para obtenemos varios valores de pi
# * paso 6: calculo el promedio y obtengo una muy buena aproximacion de pi

# %%
pi_avg = 0
pi_value_list = []
n = 1000
intentos = 100
for i in range(intentos):
    value = 0
    x = np.random.uniform(0, 1, n)
    y = np.random.uniform(0, 1, n)
    for j in range(n):
        z = np.sqrt(x[j]*x[j] + y[j]*y[j])
        if z<=1:
            value+=1
        
    float_value = float(value)
    pi_value = 4*float_value/n
    pi_value_list.append(pi_value)
    pi_avg += pi_value

pi = pi_avg/intentos
print(pi)
plt.plot(pi_value_list)
# Out:
# 3.1414467999999998
